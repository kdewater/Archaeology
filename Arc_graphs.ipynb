# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
file_path = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\NS_arch_sites_with_elevation.csv'
pts = pd.read_csv(file_path)

# Strip whitespace from column names
pts.columns = pts.columns.str.strip()

# Sort the DataFrame by 'Name' column
pts_sorted = pts.sort_values('Name')

# Set the desired width of the figure (half of the original width)
half_width = len(pts_sorted) * 0.25  # Adjust width based on the number of data points
fig_size = (half_width, 5)  # Maintain the height

# Create the figure and axes for the plot with adjusted width
plt.subplots(figsize=fig_size)

# Plot the scatter points with sorted data using the correct column names
plt.scatter(pts_sorted['Name'], pts_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
plt.scatter(pts_sorted['Name'], pts_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
plt.scatter(pts_sorted['Name'], pts_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)

# Plot lines with corrected colors and labels
plt.plot(pts_sorted['Name'], [1.18872] * len(pts_sorted), label='2100', linestyle='--', color='black')  # 3.9 ft by 2100
plt.plot(pts_sorted['Name'], [0.4572] * len(pts_sorted), label='2050', color='black')  # 1.5 ft by 2050
plt.plot(pts_sorted['Name'], [0] * len(pts_sorted), color='#9d9d9d', label='Current')  # January storm event levels

# Adjust the plot limits, labels, and legend
plt.ylim(-3, 12)  # Set a larger y-axis range to accommodate all points
plt.ylabel('Elevation above HAT (m)')
plt.xlabel('Borden Number')

# Add the title at the top center and move it down
plt.title('Nova Scotia', y=.9)  # Adjust the y value to move the title down

# Customize x-axis ticks to label every tenth Longitude value at an angle
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Move the legend to the right side of the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust the layout to prevent cutting off the x-axis label
plt.tight_layout()

# # Define the file path for saving the plot image
# output_file_path = r"D:\Users\Classroom\Desktop\DeWater_Archaeology\NS_threat_graph7.png"

# # Save the plot to the specified file path with specified dpi (dots per inch)
# plt.savefig(output_file_path, dpi=600)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the new CSV file
file_path = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\maine\Cobscook_arch_sites_with_elevation.csv'
pts = pd.read_csv(file_path)

# Strip whitespace from column names
pts.columns = pts.columns.str.strip()

# Check the columns to ensure they match the expected names
print(pts.columns)

# Filter and sort the DataFrame based on the updated columns
pts_sorted = pts.sort_values('MHPC Site Number')[
    (pts['MHW_min_within_5m'] > -1000) | 
    (pts['MHW_mean_within_5m'] > -1000) | 
    (pts['MHW_max_within_5m'] > -1000)
]

# Plot the scatter points with sorted data using the correct column names
plt.scatter(pts_sorted['MHPC Site Number'], pts_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
plt.scatter(pts_sorted['MHPC Site Number'], pts_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
plt.scatter(pts_sorted['MHPC Site Number'], pts_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)

# Plot lines with corrected colors and labels
plt.plot(pts_sorted['MHPC Site Number'], [1.112 + 1.18872] * len(pts_sorted), label='2100', linestyle='--', color='black')  # 3.9 ft by 2100
plt.plot(pts_sorted['MHPC Site Number'], [1.112 + 0.4572] * len(pts_sorted), label='2050', color='black')  # 1.5 ft by 2050
plt.plot(pts_sorted['MHPC Site Number'], [1.112] * len(pts_sorted), color='#9d9d9d', label='Current')  # January storm event levels

# Adjust the plot limits, labels, and legend
plt.ylim(-2, 10.5)  # Set the y-axis range with minimum -2
plt.ylabel('Elevation above HAT (m)')
plt.xlabel('Maine Historic Preservation Commission Site Number')

# Set the figure size to accommodate all x-axis labels and fit the plot vertically
fig_size = (len(pts_sorted) * 0.2, 6)  # Increased height for better vertical fit
plt.gcf().set_size_inches(fig_size)

# Customize x-axis ticks with specific positions and labels
tick_positions = pts_sorted['MHPC Site Number']
tick_labels = pts_sorted['MHPC Site Number']
plt.xticks(tick_positions, tick_labels, rotation=90)

# Move the legend to the right side of the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Add a title to the plot
plt.title('Maine')

# Adjust the layout to prevent cutting off the x-axis label and title
plt.tight_layout()

# # Define the file path for saving the plot image
# file_path = r"C:\Users\kdewa\Documents\Archaeology_GIS\FINAL_FIGURES\Sites_SLR_threat_graph5.png"

# # Save the plot to the specified file path with specified dpi (dots per inch)
# plt.savefig(file_path, dpi=600)

# Show the plot
plt.show()
# Out:
# Index(['Unnamed: 0', 'MHPC Site Number', 'Town', 'RSPF Site Number',
#        'Alternate Name(s)', 'Dates of visits', 'Notes', 'Notable references',
#        'Landowner', 'Access Notes', 'NAD83 Easting', 'NAD83 Northing',
#        'Coords updated from MHPC data', 'MHPC Forms Updated', 'Visited',
#        'Excavations by NEAS', 'Excavations by Us', 'Located',
#        'Unable to Locate', 'Confirmed Destroyed', 'geometry', 'NAVD88', 'HAT',
#        'MHW_mean_within_5m', 'MHW_min_within_5m', 'MHW_max_within_5m',
#        'MHW_mean_within_10m', 'MHW_min_within_10m', 'MHW_max_within_10m',
#        'MHW_mean_within_20m', 'MHW_min_within_20m', 'MHW_max_within_20m',
#        'MHW_mean_within_40m', 'MHW_min_within_40m', 'MHW_max_within_40m'],
#       dtype='object')
# C:\Users\Classroom\AppData\Local\Temp\ipykernel_3740\3092798992.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pts_sorted = pts.sort_values('MHPC Site Number')[

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths for the CSV files
file_path_ns = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\NS_arch_sites_with_elevation.csv'
file_path_me = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\maine\Cobscook_arch_sites_with_elevation.csv'

# Load the data from the CSV files
pts_ns = pd.read_csv(file_path_ns)
pts_me = pd.read_csv(file_path_me)

# Strip whitespace from column names
pts_ns.columns = pts_ns.columns.str.strip()
pts_me.columns = pts_me.columns.str.strip()

# Sort and filter the data for Nova Scotia
pts_ns_sorted = pts_ns.sort_values('Name')
half_width_ns = len(pts_ns_sorted) * 0.25
fig_size_ns = (half_width_ns, 5)

# Sort and filter the data for Maine
pts_me_sorted = pts_me.sort_values('MHPC Site Number')[
    (pts_me['MHW_min_within_5m'] > -1000) | 
    (pts_me['MHW_mean_within_5m'] > -1000) | 
    (pts_me['MHW_max_within_5m'] > -1000)
]
fig_size_me = (len(pts_me_sorted) * 0.2, 6)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(max(fig_size_ns[0], fig_size_me[0]), 11), sharex=True)

# Plot for Nova Scotia
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax1.plot(pts_ns_sorted['Name'], [1.18872] * len(pts_ns_sorted), label='2100', linestyle='--', color='black')
ax1.plot(pts_ns_sorted['Name'], [0.4572] * len(pts_ns_sorted), label='2050', color='black')
ax1.plot(pts_ns_sorted['Name'], [0] * len(pts_ns_sorted), color='#9d9d9d', label='Current')
ax1.set_ylim(-3, 12)
ax1.set_ylabel('Elevation above HAT (m)')
ax1.set_title('Nova Scotia', y=0.9)
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax1.tick_params(axis='x', rotation=90)

# Plot for Maine
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 1.18872] * len(pts_me_sorted), label='2100', linestyle='--', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 0.4572] * len(pts_me_sorted), label='2050', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112] * len(pts_me_sorted), color='#9d9d9d', label='Current')
ax2.set_ylim(-2, 10.5)
ax2.set_ylabel('Elevation above HAT (m)')
ax2.set_xlabel('Site Number')
ax2.set_title('Maine')
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax2.tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()

# # Define the file path for saving the combined plot image
# output_file_path = r"C:\Users\kdewa\Documents\Archaeology_GIS\FINAL_FIGURES\Combined_SLR_threat_graph.png"

# # Save the combined plot to the specified file path with specified dpi (dots per inch)
# plt.savefig(output_file_path, dpi=600)

# Show the plot
plt.show()
# Out:
# C:\Users\Classroom\AppData\Local\Temp\ipykernel_3740\3136990172.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pts_me_sorted = pts_me.sort_values('MHPC Site Number')[

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths for the CSV files
file_path_ns = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\NS_arch_sites_with_elevation.csv'
file_path_me = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\maine\Cobscook_arch_sites_with_elevation.csv'

# Load the data from the CSV files
pts_ns = pd.read_csv(file_path_ns)
pts_me = pd.read_csv(file_path_me)

# Strip whitespace from column names
pts_ns.columns = pts_ns.columns.str.strip()
pts_me.columns = pts_me.columns.str.strip()

# Sort the data for Nova Scotia
pts_ns_sorted = pts_ns.sort_values('Name')

# Sort and filter the data for Maine
pts_me_sorted = pts_me.sort_values('MHPC Site Number')[
    (pts_me['MHW_min_within_5m'] > -1000) | 
    (pts_me['MHW_mean_within_5m'] > -1000) | 
    (pts_me['MHW_max_within_5m'] > -1000)
]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(max(len(pts_ns_sorted) * 0.25, len(pts_me_sorted) * 0.2), 11), sharex=False)

# Plot for Nova Scotia
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax1.plot(pts_ns_sorted['Name'], [1.18872] * len(pts_ns_sorted), label='2100', linestyle='--', color='black')
ax1.plot(pts_ns_sorted['Name'], [0.4572] * len(pts_ns_sorted), label='2050', color='black')
ax1.plot(pts_ns_sorted['Name'], [0] * len(pts_ns_sorted), color='#9d9d9d', label='Current')
ax1.set_ylim(-3, 12)
ax1.set_ylabel('Elevation above HAT (m)')
ax1.set_title('Nova Scotia', y=0.9)
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax1.tick_params(axis='x', rotation=90)

# Plot for Maine
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 1.18872] * len(pts_me_sorted), label='2100', linestyle='--', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 0.4572] * len(pts_me_sorted), label='2050', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112] * len(pts_me_sorted), color='#9d9d9d', label='Current')
ax2.set_ylim(-2, 10.5)
ax2.set_ylabel('Elevation above HAT (m)')
ax2.set_xlabel('Maine Historic Preservation Commission Site Number')
ax2.set_title('Maine', y=0.9)
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax2.tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()

# # Define the file path for saving the combined plot image
# output_file_path = r"C:\Users\kdewa\Documents\Archaeology_GIS\FINAL_FIGURES\Combined_SLR_threat_graph.png"

# # Save the combined plot to the specified file path with specified dpi (dots per inch)
# plt.savefig(output_file_path, dpi=600)

# Show the plot
plt.show()
# Out:
# C:\Users\Classroom\AppData\Local\Temp\ipykernel_3740\2716778145.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pts_me_sorted = pts_me.sort_values('MHPC Site Number')[

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths for the CSV files
file_path_ns = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\NS_arch_sites_with_elevation.csv'
file_path_me = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\maine\Cobscook_arch_sites_with_elevation.csv'

# Load the data from the CSV files
pts_ns = pd.read_csv(file_path_ns)
pts_me = pd.read_csv(file_path_me)

# Strip whitespace from column names
pts_ns.columns = pts_ns.columns.str.strip()
pts_me.columns = pts_me.columns.str.strip()

# Sort the data for Nova Scotia
pts_ns_sorted = pts_ns.sort_values('Name')

# Sort and filter the data for Maine
pts_me_sorted = pts_me.sort_values('MHPC Site Number')[
    (pts_me['MHW_min_within_5m'] > -1000) | 
    (pts_me['MHW_mean_within_5m'] > -1000) | 
    (pts_me['MHW_max_within_5m'] > -1000)
]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(max(len(pts_ns_sorted) * 0.25, len(pts_me_sorted) * 0.2), 11), sharex=False)

# Plot for Nova Scotia
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax1.plot(pts_ns_sorted['Name'], [1.18872] * len(pts_ns_sorted), label='2100', linestyle='--', color='black')
ax1.plot(pts_ns_sorted['Name'], [0.4572] * len(pts_ns_sorted), label='2050', color='black')
ax1.plot(pts_ns_sorted['Name'], [0] * len(pts_ns_sorted), color='#9d9d9d', label='Current')
ax1.set_ylim(-3, 12)
ax1.set_ylabel('Elevation above HAT (m)')
ax1.set_title('Nova Scotia Sites', y=0.9)
ax1.set_xlabel('Borden Number')  # Add x-axis label for Nova Scotia
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax1.tick_params(axis='x', rotation=90)

# Plot for Maine
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 1.18872] * len(pts_me_sorted), label='2100', linestyle='--', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 0.4572] * len(pts_me_sorted), label='2050', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112] * len(pts_me_sorted), color='#9d9d9d', label='Current')
ax2.set_ylim(-2, 10.5)
ax2.set_ylabel('Elevation above HAT (m)')
ax2.set_xlabel('Maine Historic Preservation Commission Site Number')
ax2.set_title('Maine Sites', y=0.9)
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax2.tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()

# # Define the file path for saving the combined plot image
# output_file_path = r"C:\Users\kdewa\Documents\Archaeology_GIS\FINAL_FIGURES\Combined_SLR_threat_graph.png"

# # Save the combined plot to the specified file path with specified dpi (dots per inch)
# plt.savefig(output_file_path, dpi=600)

# Show the plot
plt.show()
# Out:
# C:\Users\Classroom\AppData\Local\Temp\ipykernel_3740\3697166147.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pts_me_sorted = pts_me.sort_values('MHPC Site Number')[

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths for the CSV files
file_path_ns = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\NS_arch_sites_with_elevation.csv'
file_path_me = r'D:\Users\Classroom\Desktop\DeWater_Archaeology\maine\Cobscook_arch_sites_with_elevation.csv'

# Load the data from the CSV files
pts_ns = pd.read_csv(file_path_ns)
pts_me = pd.read_csv(file_path_me)

# Strip whitespace from column names
pts_ns.columns = pts_ns.columns.str.strip()
pts_me.columns = pts_me.columns.str.strip()

# Sort the data for Nova Scotia
pts_ns_sorted = pts_ns.sort_values('Name')

# Sort and filter the data for Maine
pts_me_sorted = pts_me.sort_values('MHPC Site Number')[
    (pts_me['MHW_min_within_5m'] > -1000) | 
    (pts_me['MHW_mean_within_5m'] > -1000) | 
    (pts_me['MHW_max_within_5m'] > -1000)
]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(max(len(pts_ns_sorted) * 0.25, len(pts_me_sorted) * 0.2), 11), sharex=False)

# Plot for Nova Scotia
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax1.scatter(pts_ns_sorted['Name'], pts_ns_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax1.plot(pts_ns_sorted['Name'], [1.18872] * len(pts_ns_sorted), label='2100', linestyle='--', color='black')
ax1.plot(pts_ns_sorted['Name'], [0.4572] * len(pts_ns_sorted), label='2050', color='black')
ax1.plot(pts_ns_sorted['Name'], [0] * len(pts_ns_sorted), color='#9d9d9d', label='Current')
ax1.set_ylim(-3, 12)
ax1.set_ylabel('Elevation above HAT (m)')
ax1.set_title('Nova Scotia Sites', loc='left', x=0.03, y=0.9)  # Move title to the left
ax1.set_xlabel('Borden Number')
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax1.tick_params(axis='x', rotation=90)

# Plot for Maine
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_max_within_5m'], s=15, color='#deebf7', label='Maximum', edgecolors='black', linewidth=0.2)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_mean_within_5m'], s=15, label='Mean', color='#6baed6', edgecolors='black', linewidth=0.1)
ax2.scatter(pts_me_sorted['MHPC Site Number'], pts_me_sorted['MHW_min_within_5m'], s=15, label='Minimum', color='black', edgecolors='black', linewidth=0.1)
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 1.18872] * len(pts_me_sorted), label='2100', linestyle='--', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112 + 0.4572] * len(pts_me_sorted), label='2050', color='black')
ax2.plot(pts_me_sorted['MHPC Site Number'], [1.112] * len(pts_me_sorted), color='#9d9d9d', label='Current')
ax2.set_ylim(-2, 10.5)
ax2.set_ylabel('Elevation above HAT (m)')
ax2.set_xlabel('Maine Historic Preservation Commission Site Number')
ax2.set_title('Maine Sites', loc='left', x=0.03, y=0.9)  # Move title to the left
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax2.tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()

# Define the file path for saving the combined plot image
output_file_path = r"D:\Users\Classroom\Desktop\DeWater_Archaeology\maine\CombonedFigure.png"

# Save the combined plot to the specified file path with specified dpi (dots per inch)
plt.savefig(output_file_path, dpi=600)

# Show the plot
plt.show()
# Out:
# C:\Users\Classroom\AppData\Local\Temp\ipykernel_3740\2436546066.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pts_me_sorted = pts_me.sort_values('MHPC Site Number')[
